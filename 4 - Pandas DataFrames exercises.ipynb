# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.4.3

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# This is a very basic way, without including any data, index or columns

empty_df = pd.DataFrame()
print(empty_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# This is another way, where we assign None to the key components of the DataFrame

pd.DataFrame(data=[None],
             index=[None],
             columns=[None])
# Out:
#       None
# None  None

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# This is one way, setting the data and columns name first, then the index

marvel_heroes = pd.DataFrame(data=[['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]], columns=['Name','Gender','Year of Birth'])

marvel_heroes.index = marvel_heroes['Name']

marvel_heroes
# Out:
#                               Name  Gender  Year of Birth
# Name
# Spider-Man              Spider-Man    male           1962
# Captain America    Captain America    male           1941
# Wolverine                Wolverine    male           1974
# Iron Man                  Iron Man    male           1963
# Thor                          Thor    male           1963
# Thing                        Thing    male           1961
# Mister Fantastic  Mister Fantastic    male           1961
# Hulk                          Hulk    male           1962
# Beast                        Beast    male           1963
# Invisible Woman    Invisible Woman  female           1961
# Storm                        Storm  female           1975
# Namor                        Namor    male           1939
# Hawkeye                    Hawkeye    male           1964
# Daredevil                Daredevil    male           1964
# Doctor Strange      Doctor Strange    male           1963
# Hank Pym                  Hank Pym    male           1962
# Scarlet Witch        Scarlet Witch  female           1964
# Wasp                          Wasp  female           1963
# Black Widow            Black Widow  female           1964
# Vision                      Vision    male           1968

# %%
# This is another way, much simpler where we get directly the variable where the data is located

marvel_df = pd.DataFrame(data=marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
# This is one way, at the same time when we create the DataFrame

marvel_df =  pd.DataFrame(data=marvel_data, columns=['Name','Gender','Year of Birth'])
marvel_df
# Out:
#                 Name  Gender  Year of Birth
# 0         Spider-Man    male           1962
# 1    Captain America    male           1941
# 2          Wolverine    male           1974
# 3           Iron Man    male           1963
# 4               Thor    male           1963
# 5              Thing    male           1961
# 6   Mister Fantastic    male           1961
# 7               Hulk    male           1962
# 8              Beast    male           1963
# 9    Invisible Woman  female           1961
# 10             Storm  female           1975
# 11             Namor    male           1939
# 12           Hawkeye    male           1964
# 13         Daredevil    male           1964
# 14    Doctor Strange    male           1963
# 15          Hank Pym    male           1962
# 16     Scarlet Witch  female           1964
# 17              Wasp  female           1963
# 18       Black Widow  female           1964
# 19            Vision    male           1968

# %%
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# If we use set_index we will assign a number to become the Index

marvel_df.set_index(['name'])
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# This is one way, using columns to specify the column name

marvel_df.drop(columns=['name'])
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
#marvel_df = marvel_df.drop(columns=['name'])
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# Here we drop the rows without affecting the existing DataFrame
marvel_df.drop(['Namor','Hulk'], axis=0)
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %%
# Here we affect the DataFrame once we dropped these rows
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# There are multiple ways, one very simple is by using head

marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
# Other options is using loc when we use the names of the characthers, and iloc for spatial position

#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,]
#marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# We can use iloc indicating the number where we start slicing and nothing at the end

#marvel_df.tail()
marvel_df.iloc[-5:]
# Out:
#                    sex  first_appearance
# name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1963
# Black Widow     female              1964
# Vision            male              1968

# %%
# Also we can use tail to show the last 5 elements

#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
#marvel_df.iloc[-5:,]
marvel_df.tail()
# Out:
#                    sex  first_appearance
# name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1963
# Black Widow     female              1964
# Vision            male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# We can use iloc for spatial position of rows and columns

marvel_df.iloc[:5,0]
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %%
# If we use to_frame we can show the information in the DataFrame form

#marvel_df.iloc[:5,]['sex'].to_frame()
marvel_df.iloc[:5,].sex.to_frame()
#marvel_df.head().sex.to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# We use iloc to slice by spatial position 

marvel_df.iloc[1:-1,].first_appearance.to_frame()
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# This is one way

marvel_df.iloc[[0, -1]]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %%
# This is another way, indicating the column names

marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
#marvel_df.iloc[[0, -1],]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
marvel_df.loc['Vision', 'first_appearance'] = 1964
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# We can calculate the difference in years by substracting the current year from the date that is in the column first_appearance

marvel_df['years_since'] = 2023 - marvel_df['first_appearance']
marvel_df
# Out:
#                               name     sex  first_appearance  years_since
# name
# Spider-Man              Spider-Man    male              1962           61
# Captain America    Captain America    male              1941           82
# Wolverine                Wolverine    male              1974           49
# Iron Man                  Iron Man    male              1963           60
# Thor                          Thor    male              1963           60
# Thing                        Thing    male              1961           62
# Mister Fantastic  Mister Fantastic    male              1961           62
# Hulk                          Hulk    male              1962           61
# Beast                        Beast    male              1963           60
# Invisible Woman    Invisible Woman  female              1961           62
# Storm                        Storm  female              1975           48
# Namor                        Namor    male              1939           84
# Hawkeye                    Hawkeye    male              1964           59
# Daredevil                Daredevil    male              1964           59
# Doctor Strange      Doctor Strange    male              1963           60
# Hank Pym                  Hank Pym    male              1962           61
# Scarlet Witch        Scarlet Witch  female              1964           59
# Wasp                          Wasp  female              1963           60
# Black Widow            Black Widow  female              1964           59
# Vision                      Vision    male              1964           59

# %%
marvel_df['years_since'] = 2018 - marvel_df['first_appearance']
marvel_df
# Out:
#                      sex  first_appearance  years_since
# name
# Spider-Man          male              1962           56
# Captain America     male              1941           77
# Wolverine           male              1974           44
# Iron Man            male              1963           55
# Thor                male              1963           55
# Thing               male              1961           57
# Mister Fantastic    male              1961           57
# Hulk                male              1962           56
# Beast               male              1963           55
# Invisible Woman   female              1961           57
# Storm             female              1975           43
# Hawkeye             male              1964           54
# Daredevil           male              1964           54
# Doctor Strange      male              1963           55
# Scarlet Witch     female              1964           54
# Wasp              female              1963           55
# Black Widow       female              1964           54
# Vision              male              1964           54

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# I used loc to create this mask and show as a DataFrame with only the female characters

female_heroes = marvel_df.loc[marvel_df['sex'] == 'female']
female_heroes
# Out:
#                             name     sex  first_appearance  years_since
# name
# Invisible Woman  Invisible Woman  female              1961           62
# Storm                      Storm  female              1975           48
# Scarlet Witch      Scarlet Witch  female              1964           59
# Wasp                        Wasp  female              1963           60
# Black Widow          Black Widow  female              1964           59

# %%
# We can also create the mask directly without using loc

mask = marvel_df['sex'] == 'female'
mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# I used loc to create this mask and show as a DataFrame with only the female characters

male_heroes = marvel_df.loc[marvel_df['sex'] == 'male']
male_heroes
# Out:
#                               name   sex  first_appearance  years_since
# name
# Spider-Man              Spider-Man  male              1962           61
# Captain America    Captain America  male              1941           82
# Wolverine                Wolverine  male              1974           49
# Iron Man                  Iron Man  male              1963           60
# Thor                          Thor  male              1963           60
# Thing                        Thing  male              1961           62
# Mister Fantastic  Mister Fantastic  male              1961           62
# Hulk                          Hulk  male              1962           61
# Beast                        Beast  male              1963           60
# Namor                        Namor  male              1939           84
# Hawkeye                    Hawkeye  male              1964           59
# Daredevil                Daredevil  male              1964           59
# Doctor Strange      Doctor Strange  male              1963           60
# Hank Pym                  Hank Pym  male              1962           61
# Vision                      Vision  male              1964           59

# %%
# We can create this mask in a much simpler way doing this

mask = marvel_df['sex'] == 'male'
marvel_df[mask]
# Out:
#                               name   sex  first_appearance  years_since
# name
# Spider-Man              Spider-Man  male              1962           61
# Captain America    Captain America  male              1941           82
# Wolverine                Wolverine  male              1974           49
# Iron Man                  Iron Man  male              1963           60
# Thor                          Thor  male              1963           60
# Thing                        Thing  male              1961           62
# Mister Fantastic  Mister Fantastic  male              1961           62
# Hulk                          Hulk  male              1962           61
# Beast                        Beast  male              1963           60
# Namor                        Namor  male              1939           84
# Hawkeye                    Hawkeye  male              1964           59
# Daredevil                Daredevil  male              1964           59
# Doctor Strange      Doctor Strange  male              1963           60
# Hank Pym                  Hank Pym  male              1962           61
# Vision                      Vision  male              1964           59

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
more_recent = marvel_df.loc[marvel_df['first_appearance'] > 1970]
more_recent
# Out:
#                 name     sex  first_appearance  years_since
# name
# Wolverine  Wolverine    male              1974           49
# Storm          Storm  female              1975           48

# %%
mask = marvel_df['first_appearance'] > 1970
marvel_df[mask]
# Out:
#                 name     sex  first_appearance  years_since
# name
# Wolverine  Wolverine    male              1974           49
# Storm          Storm  female              1975           48

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)
marvel_df[mask]
# Out:
#         name     sex  first_appearance  years_since
# name
# Storm  Storm  female              1975           48

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
marvel_df.describe()
# Out:
#        first_appearance  years_since
# count         20.000000    20.000000
# mean        1961.650000    61.350000
# std            8.298859     8.298859
# min         1939.000000    48.000000
# 25%         1961.750000    59.000000
# 50%         1963.000000    60.000000
# 75%         1964.000000    61.250000
# max         1975.000000    84.000000

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# This is one way
marvel_df['first_appearance'].mean()
# Out:
# 1961.65

# %%
# This is another way

np.mean(marvel_df.first_appearance)
#marvel_df.first_appearance.mean()
# Out:
# 1961.65

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# Out:
# 1939

# %%
#np.min(marvel_df.first_appearance)
marvel_df.first_appearance.min()
# Out:
# 1939

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here
mask = marvel_df['first_appearance'] == marvel_df['first_appearance'].min()
marvel_df[mask]
# Out:
#         name   sex  first_appearance  years_since
# name
# Namor  Namor  male              1939           84

# %%
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]
# Out:
#         name   sex  first_appearance  years_since
# name
# Namor  Namor  male              1939           84

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# This is one way using inplace True
marvel_df.reset_index(inplace=True)
marvel_df
# Out:
#     index              name     sex  first_appearance
# 0       0        Spider-Man    male              1962
# 1       1   Captain America    male              1941
# 2       2         Wolverine    male              1974
# 3       3          Iron Man    male              1963
# 4       4              Thor    male              1963
# 5       5             Thing    male              1961
# 6       6  Mister Fantastic    male              1961
# 7       7              Hulk    male              1962
# 8       8             Beast    male              1963
# 9       9   Invisible Woman  female              1961
# 10     10             Storm  female              1975
# 11     11             Namor    male              1939
# 12     12           Hawkeye    male              1964
# 13     13         Daredevil    male              1964
# 14     14    Doctor Strange    male              1963
# 15     15          Hank Pym    male              1962
# 16     16     Scarlet Witch  female              1964
# 17     17              Wasp  female              1963
# 18     18       Black Widow  female              1964
# 19     19            Vision    male              1968

# %%
marvel_df = marvel_df.reset_index()
marvel_df
# Out:
#     level_0  index              name     sex  first_appearance
# 0         0      0        Spider-Man    male              1962
# 1         1      1   Captain America    male              1941
# 2         2      2         Wolverine    male              1974
# 3         3      3          Iron Man    male              1963
# 4         4      4              Thor    male              1963
# 5         5      5             Thing    male              1961
# 6         6      6  Mister Fantastic    male              1961
# 7         7      7              Hulk    male              1962
# 8         8      8             Beast    male              1963
# 9         9      9   Invisible Woman  female              1961
# 10       10     10             Storm  female              1975
# 11       11     11             Namor    male              1939
# 12       12     12           Hawkeye    male              1964
# 13       13     13         Daredevil    male              1964
# 14       14     14    Doctor Strange    male              1963
# 15       15     15          Hank Pym    male              1962
# 16       16     16     Scarlet Witch  female              1964
# 17       17     17              Wasp  female              1963
# 18       18     18       Black Widow  female              1964
# 19       19     19            Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# This is one way to make the histogram plot

x = marvel_df['first_appearance']
plt.hist(x, bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# This is another way, much simpler

plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 15.,  0.,  1.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
