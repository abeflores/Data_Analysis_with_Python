# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress


def draw_plot():
    # Read data from file
    data  = pd.read_csv('epa-sea-level.csv')

    # Create scatter plot
    fig, ax = plt.subplots()
    ax.scatter(data['Year'], data['CSIRO Adjusted Sea Level'])

    # Create first line of best fit
    slope, intercept, r_value, p_value, std_err = linregress(data[data['Year'] >= 2000]['Year'], 
                                                            data[data['Year'] >= 2000]['CSIRO Adjusted Sea Level'])
    x = [2000, 2050]
    y = [slope * x[0] + intercept, slope * x[1] + intercept]
    ax.plot(x, y, color='red')

    # Create second line of best fit
    slope_all, intercept_all, r_value_all, p_value_all, std_err_all = linregress(data['Year'], 
                                                                                 data['CSIRO Adjusted Sea Level'])
    x_all = [1880, 2050]
    y_all = [slope_all * x_all[0] + intercept_all, slope_all * x_all[1] + intercept_all]
    ax.plot(x_all, y_all, color='blue')

    # Add labels and title
    plt.xlabel('Year')
    plt.ylabel('Sea Level (inches)')
    plt.title('Rise in Sea Level')
    plt.show()
    
    # Save plot and return data for testing (DO NOT MODIFY)
    plt.savefig('sea_level_plot.png')
    return plt.gca()

# %%
draw_plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
# Read data from file
data  = pd.read_csv('epa-sea-level.csv')

# %%
data.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
 # Create scatter plot
x = data['Year']
y = data['CSIRO Adjusted Sea Level']

# %%
plt.scatter(x, y)
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')
plt.show()

# %%
 # Create first line of best fit

# Create a figure and axis
fig, ax = plt.subplots()

# Create a scatter plot using the Year and CSIRO Adjusted Sea Level columns
ax.scatter(data['Year'], data['CSIRO Adjusted Sea Level'])

# Get the slope and y-intercept of the line of best fit
slope, intercept, r_value, p_value, std_err = linregress(data['Year'], data['CSIRO Adjusted Sea Level'])

# Plot the line of best fit
x = [1880, 2050]
y = [slope * x[0] + intercept, slope * x[1] + intercept]
ax.plot(x, y, color='red')

# Show the plot
plt.show()

# %%
# Create second line of best fit

# Create a figure and axis
fig, ax = plt.subplots()

# Create a scatter plot using the Year and CSIRO Adjusted Sea Level columns
ax.scatter(data['Year'][data['Year'] >= 2000], data['CSIRO Adjusted Sea Level'][data['Year'] >= 2000])

# Get the slope and y-intercept of the line of best fit, using data from year 2000 and later
slope, intercept, r_value, p_value, std_err = linregress(data[data['Year'] >= 2000]['Year'], 
                                                         data[data['Year'] >= 2000]['CSIRO Adjusted Sea Level'])

# Plot the line of best fit
x = [2000, 2050]
y = [slope * x[0] + intercept, slope * x[1] + intercept]
ax.plot(x, y, color='red')

# Show the plot
plt.show()

# %%
# This code creates a scatter plot of the data from the Year and CSIRO Adjusted Sea Level columns
# It plots the data points from the Year column starting at 2000 to 2050
# A line of best fit is then calculated from 2000 to the most recent year in the dataset
# This line is then plotted in red on the scatter plot
# The code also plots all the data points in blue on the same scatter plot

fig, ax = plt.subplots()
ax.scatter(data['Year'][data['Year'] >= 2000], data['CSIRO Adjusted Sea Level'][data['Year'] >= 2000])
slope, intercept, r_value, p_value, std_err = linregress(data['Year'][data['Year'] >= 2000], 
                                                         data['CSIRO Adjusted Sea Level'][data['Year'] >= 2000])
x = [2000, 2050]
y = [slope * x[0] + intercept, slope * x[1] + intercept]
ax.plot(x, y, color='red')
ax.plot(data['Year'], data['CSIRO Adjusted Sea Level'], color='blue')
plt.show()

# %%
# This code creates a scatter plot of the data from the Year and CSIRO Adjusted Sea Level columns
# It plots the data points from the Year column starting at 1880 to 2050
# A line of best fit is then calculated from 2000 to the most recent year in the dataset
# This line is then plotted in red on the scatter plot
# The code also calculates a line of best fit from 1880 to 2050 and plots it in blue on the same scatter plot

fig, ax = plt.subplots()
ax.scatter(data['Year'], data['CSIRO Adjusted Sea Level'])

slope, intercept, r_value, p_value, std_err = linregress(data[data['Year'] >= 2000]['Year'], 
                                                         data[data['Year'] >= 2000]['CSIRO Adjusted Sea Level'])
x = [2000, 2050]
y = [slope * x[0] + intercept, slope * x[1] + intercept]
ax.plot(x, y, color='red')

slope_all, intercept_all, r_value_all, p_value_all, std_err_all = linregress(data['Year'], data['CSIRO Adjusted Sea Level'])
x_all = [1880, 2050]
y_all = [slope_all * x_all[0] + intercept_all, slope_all * x_all[1] + intercept_all]
ax.plot(x_all, y_all, color='blue')

plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')
plt.show()

# %%
def draw_plot():

    data  = pd.read_csv('epa-sea-level.csv')
    fig, ax = plt.subplots()
    ax.scatter(data['Year'], data['CSIRO Adjusted Sea Level'])

    slope, intercept, r_value, p_value, std_err = linregress(data[data['Year'] >= 2000]['Year'], 
                                                            data[data['Year'] >= 2000]['CSIRO Adjusted Sea Level'])
    x = [2000, 2050]
    y = [slope * x[0] + intercept, slope * x[1] + intercept]
    ax.plot(x, y, color='red')

    slope_all, intercept_all, r_value_all, p_value_all, std_err_all = linregress(data['Year'], data['CSIRO Adjusted Sea Level'])
    x_all = [1880, 2050]
    y_all = [slope_all * x_all[0] + intercept_all, slope_all * x_all[1] + intercept_all]
    ax.plot(x_all, y_all, color='blue')

    plt.xlabel('Year')
    plt.ylabel('Sea Level (inches)')
    plt.title('Rise in Sea Level')
    plt.show()

    plt.savefig('sea_level_plot.png')
    return plt.gca()

# %%
draw_plot()
# Out:
# <AxesSubplot:>

# %%
# We can return the values of our data for testing using plt.gca()

ax = plt.gca()
data_test = ax.scatter(data['Year'], data['CSIRO Adjusted Sea Level'])

# %%
# We can return the values for testing of the 2 lines of best fit using plt.gca()

ax = plt.gca()
line1_data = ax.plot(x, y, color='red')
line2_data = ax.plot(x_all, y_all, color='blue')
